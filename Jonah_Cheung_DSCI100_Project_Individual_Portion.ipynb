# %%
library(tidyverse)
library(repr)
library(tidymodels)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ...

# %%
players<-read_csv("https://raw.githubusercontent.com/jonahblizzard5058-coder/Jonah-Cheung-DSCI-100-Project/refs/heads/main/players.csv")
players
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# 10  Veteran     TRUE
# 11  Veteran     TRUE
# 12  Pro         TRUE
# 13  Beginner    TRUE
# 14  Amateur     TRUE
# 15  Veteran     TRUE
# 16  Amateur    FALSE
# 17  Beginner    TRUE
# 18  Amateur     TRUE
# 19  Amateur     TRUE
# 20  Regular     TRUE
# 21  Regular     TRUE
# 22  Amateur    FALSE
# 23  Beginner    TRUE
# 24  Beginner    TRUE
# 25  Amateur     TRUE
# ...

# %%
sessions<-read_csv("https://raw.githubusercontent.com/jonahblizzard5058-coder/Jonah-Cheung-DSCI-100-Project/refs/heads/main/sessions.csv")
sessions
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#      hashedEmail
# 1    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3    f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5    36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6    bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 7    fd6563a4e0f6f4273580e5fedbd8dda64990447aea5a33cbb5e894a3867ca44d
# 8    ad6390295640af1ed0e45ffc58a53b2d9074b0eea694b16210addd44d7c81f83
# ...

# %% [markdown]
# 1. Data Description:
#
# players.csv:
#
# | Variable       | Type                       | Description                                                                                     | Potential Issues                                                   |
# | -------------- | -------------------------- | ----------------------------------------------------------------------------------------------- | ------------------------------------------------------------------ |
# | `experience`   | Categorial                    | Described as Amateur, Beginner, Regular, Pro, or Veteran.                    | The data collected was most likely self reported. Therefore, experience, as a categorial variable, is somewhat subjective.               |
# | `subscribe`    | Binary (TRUE/FALSE) | Indicator for whether the player subscribed to the game-related newsletter. |         |
# | `hashedEmail`  | Character                  | Player identity which can be used to search for particular players in the `sessions.csv`.                     | |
# | `played_hours` | Quantitative                    | Total number of hours the player has played.                                                    | I have identified many zero values in this category which will impact the data during interpretation if not removed.           |
# | `name`         | Character                  | Player display name.                                                                   |  |
# | `gender`       | Categorical (character)    | Self-reported gender of the player.                                                             |               |
# | `Age`          | Quantitative         | Age of the player in years.                                                                     | The mean average age of the players being 21, meaninger there isn't an accurate representation of all age groups.                  |
#
#
# sessions.csv:
#
# | Variable              | Type                         | Description                                                       | Potential Issues                                                                                                               |
# | --------------------- | ---------------------------- | ----------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------ |
# | `hashedEmail`         | Character                    | Player identification that can be used to bridge the two data sets.                    | Must match between files; missing or mismatched IDs could cause potential issues.                                                         |
# | `start_time`          | Character (DD/MM/YYYY HH:MM) | Human-readable formatted timestamp for session start time, down to the minute.             | Must be formatted in a way the computer can understand when running models. |
# | `end_time`            | Character (DD/MM/YYYY HH:MM) | Human-readable formatted timestamp for session end.               |                                                          |
# | `original_start_time` | Numeric (~1.7e+12)           | Unix timestamp in milliseconds since 1970-01-01 00:00:00 UTC. (https://www.unixtimestamp.com/)|                              |
# | `original_end_time`   | Numeric (~1.7e+12)           | Unix timestamp in milliseconds for session end.                   | These unix timestamps seem to be rounded too high so the start and end time are almost all identical.                         |

# %% [markdown]
# 2. Questions:
#
# Broad question:
#
# We would like to know which "kinds" of players are most likely to contribute a large amount of data so that we can target those players in our recruiting efforts.
#
# Specific question:
#
# Can a player’s total hours played (played_hours) and age (Age) be used to predict a player's experience level (experience)?
#
# Explanation:
#
# This question will help the researchers identify patterns between player age and experience, which can support more targeted recruitment efforts. In general, players who spend more hours in the game contribute more gameplay data, making them more valuable participants for analysis. Using the players.csv dataset, I plan to create a tibble containing the three relevant columns: Age, played_hours, and experience. I will remove all observations where played_hours equals zero, since these players have not generated gameplay data and are unlikely to contribute meaningful information in the future. From there, I will create a scatter plot of age versus played hours, with player experience represented by colour.

# %% [markdown]
# 3. Exploratory Data Analysis and Visualization

# %% [markdown]
# *note: I have already read both data sets before the first portion

# %%
#compute the mean value for all quantitative variables in players.csv
players_mean<-players|>
    select(played_hours, Age)|>
    summarise(
    mean_played_hours = mean(played_hours, na.rm = TRUE),
    mean_age = mean(Age, na.rm = TRUE)
  )
players_mean
# Out:
#   mean_played_hours mean_age
# 1 5.845918          21.13918

# %%
#Make a few exploratory visualizations of the data to help you understand it

players_scatter_plot<-players|>
    filter(played_hours > 0) |>
    ggplot(aes(x = Age, y = played_hours, colour = experience, shape = experience))+
    geom_point(alpha=0.7)+
    labs(title = "Relationship between Player Age, Played Hours, and Experience", x = "Player Age", y = "Hours Spent on the Server", colour = "Player Experience")
players_scatter_plot
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# *note: Observations with zero played hours were removed prior to calculating the means. These players did not actively contribute gameplay data, so excluding them ensures that the summary statistics reflect only active participants.
#
# observation: The 3 players with the longest play time are all "regulars" regarding experience. Otherwise, there is no obvious trend between these three variables. This ambiguity may be a problem for when I am analyzing this data to solve my question.

# %%
#Histogram to observe the age distribution of the data
options(repr.plot.width = 17, repr.plot.height = 6)  

players_age_histogram<-ggplot(players, aes(x = Age)) +
  geom_histogram(binwidth = 1) +
  labs(
    title = "Distribution of Player Ages",
    x = "Age (years)",
    y = "Number of Players"
    )+
    scale_x_continuous(breaks = seq(min(players$Age, na.rm = TRUE), 
                                  max(players$Age, na.rm = TRUE), by = 1))
players_age_histogram
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title

# %% [markdown]
# observations: the highest concentration of players seem to be from the 17-24 year old range, with 17 being the most common player age.

# %%
#Bargraph to observe the gender and subscription distribution of the data
options(repr.plot.width = 13, repr.plot.height = 6)  
players_gender_bar<-ggplot(players, aes(x = gender, fill = subscribe)) +
    geom_bar() +
    labs(title = "Gender Distribution of Players", x = "Gender", y = "Number of Players") +
    theme(axis.title = element_text(size = 15), 
         axis.text = element_text(size = 7))
players_gender_bar
# Out:
# plot without title

# %% [markdown]
# Observations: while there are more male than female subscribers, the ration of subscribed to non-subscribed players are higher in females than males, meaning there is a greater chance for a female to subscribe than a male.

# %%
#Bargraph to observe the player experience and subscription distribution of the data
options(repr.plot.width = 10, repr.plot.height = 6)  
players_experience_bar<-ggplot(players, aes(x = experience, fill = subscribe)) +
    geom_bar(width = 0.6) +
    labs(title = "Experience Distribution of Players", x = "Experience level", y = "Number of Players") +
    theme(axis.title = element_text(size = 15), 
         axis.text = element_text(size = 7))
players_experience_bar
# Out:
# plot without title

# %% [markdown]
# Observations: The ratios of subscribed to non-subscribed players are about the same across all experience levels.

# %% [markdown]
# 4. Methods and Plan
#
# I will use K-Nearest Neighbors (KNN) to predict a player’s experience level based on their total hours played and age. It works well for small to medium-sized datasets with numerical predictors like played_hours and Age. The assumption made to use this model is that people with similar age and time spent on the server have the same experience level.
# The potential weaknesses of the KNN model is if the data set doesn’t have a really obvious trend, it could be difficult to find the correct K value to get the most accurate prediction. I will evaluate the model using accuracy on a validation set and possibly cross-validation to choose the optimal value of K value.
#
# Scaling: Standardize (center and scale)  played_hours and Age so that each variable contributes equally to the distance calculation
#
#
# Data splitting: Split the dataset into training (70%) and test (30%) sets
#
#
# Validation: Use k-fold cross-validation on the training set to select the best value of k
#
# Prediction: Apply the final KNN model to the test set to evaluate its predictive performance
